# %% [markdown]
# echo "# git_practice" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/sunilmainali/git_practice.git
# git push -u origin main

# %% [markdown]
# working files------(git add)------->staging area------git commit/push----->repository

# %%
# git remote -v
# git status

# %% [markdown]
# ## best prectice for committing message
# feat: new features added
# fix: bug fixing
# refactor: refactored code that neither fix a bug nor add a feature
# docs : update the documentation
# perf: performance improvements
# style:Formatting Only eg.indentation fix,removes extra lines
# chore: donot add features and bug, mostly project maintenance eg:
#       update numpy package,remove unused package

# %% [markdown]
# The .gitignore file tells Git which files and folders should not be tracked or uploaded to the repository.
# It is important because it keeps the project clean by ignoring unnecessary, auto-generated, large,
# or sensitive files like cache, datasets, and passwords. This helps maintain security, reduces repository size,
# and makes collaboration easier.

# %%
## git branching 
# create another branch--git branch branchname
# switch to another branch --- git checkout branchname

#1.git branch brancha  
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {"id": "#VSC-c7b577ed", "language": "markdown"},
   "source": [
    "echo \"# git_practice\" >> README.md\n",
    "git init\n",
    "git add README.md\n",
    "git commit -m \"first commit\"\n",
    "git branch -M main\n",
    "git remote add origin https://github.com/sunilmainali/git_practice.git\n",
    "git push -u origin main\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {"id": "#VSC-e8ccc531", "language": "markdown"},
   "source": [
    "working files------(git add)------->staging area------git commit/push----->repository\n"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {"id": "#VSC-57dfd0d5", "language": "python"},
   "execution_count": null,
   "outputs": [],
   "source": [
    "# git remote -v\n",
    "# git status\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {"id": "#VSC-27f9a7db", "language": "markdown"},
   "source": [
    "## best prectice for committing message\n",
    "feat: new features added\n",
    "fix: bug fixing\n",
    "refactor: refactored code that neither fix a bug nor add a feature\n",
    "docs : update the documentation\n",
    "perf: performance improvements\n",
    "style:Formatting Only eg.indentation fix,removes extra lines \n",
    "chore: donot add features and bug, mostly project maintenance eg:\n",
    "      update numpy package,remove unused package\n",
    "\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {"id": "#VSC-824c9401", "language": "markdown"},
   "source": [
    "The .gitignore file tells Git which files and folders should not be tracked or uploaded to the repository.\n",
    "It is important because it keeps the project clean by ignoring unnecessary, auto-generated, large,\n",
    "or sensitive files like cache, datasets, and passwords. This helps maintain security, reduces repository size,\n",
    "and makes collaboration easier.\n"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {"id": "#VSC-18987377", "language": "python"},
   "execution_count": null,
   "outputs": [],
   "source": [
    "## git branching \n",
    "# create another branch--git branch branchname\n",
    "# switch to another branch --- git checkout branchname\n",
    "\n",
    "#1.git branch brancha  \n",
    "#2.git checkout brancha\n",
    "#3.perform ur task in brancha\n",
    "#4. add that--git add <filename>\n",
    "#5. git commit -m \"commit message\"\n",
    "# For your local branch\n",
    "# - git checkout main \n",
    "# - git merge brancha \n",
    "# - git branch -d brancha\n",
    "\n",
    "# For remote branch\n",
    "# -#5. git commit -m \"commit message\"\n",
    "# -- git push origin brancha\n",
    "# -- create pull request to the main remote branch\n",
    "# --lead developer review your code and merge that in main remote branch\n",
    "\n",
    "# --after that you goto your local and\n",
    "# -- git pull origin main  \n"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {"id": "#VSC-9800e4b7", "language": "python"},
   "execution_count": null,
   "outputs": [],
   "source": [
    "## Resolving merge conflicts\n"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "name": "python3",
   "display_name": "Python 3"
  },
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
