# %% [markdown]
# <!-- echo "# git_practice" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/sunilmainali/git_practice.git
# git push -u origin main -->

# %%
# <!-- working files------(git add)------->staging area------git commit/push----->repository -->

# %%
# git remote -v
# git status

# %% [markdown]
# <!-- ## best prectice for committing message
# feat: new features added
# fix: bug fixing
# refactor: refactored code that neither fix a bug nor add a feature
# docs : update the documentation
# perf: performance improvements
# style:Formatting Only eg.indentation fix,removes extra lines
# chore: donot add features and bug, mostly project maintenance eg:
#       update numpy package,remove unused package
#
#  -->

# %%
# <!-- The .gitignore file tells Git which files and folders should not be tracked or uploaded to the repository.
# It is important because it keeps the project clean by ignoring unnecessary, auto-generated, large,
# or sensitive files like cache, datasets, and passwords. This helps maintain security, reduces repository size,
# and makes collaboration easier. -->

# %%
# # git commands:
# git init
# git config --global user.name "your name"
# git config --global user.email "your email"
# git clone <repo url>
# git status
# git add <filename> or git add .
# git commit -m "commit message"
# git remote add origin <url>
# git push origin <branchname>
# git pull origin sm--fetch the changes from the remote branch and merge to the main
# git fetch origin <branchname>- track the changes in the remote branch only after that merge should be done.
# git checkout -- <filename>
# git restore <filename>
# git diff <filename>
# git rebase--similar to git merge
# git log
# git diff commit1 commit2

# %%
# ## rebase vs merge
# merge:
# before
# main: a
# sm: a-----b

# after:a----b
# main:a----b

# rebase:
# before
# main:a-----b
# sm:a-----c


# after
# main:a---b----c

# %%
## merge-
# preserve entire commit history of branch 

##rebase
# overwrites the commit history to make it linear

# %%
# ## git reset
# 1.create one file and commit ---A
# 2.modify that file and commit---A----B
# - git reset --soft HEAD~1 ----A( removes your file from staging area ie reverted your last commit)
# # use cases --to change wrong commit message

# --git reset --hard HEAD~1 -- it revert back your original content


# --git revert head

# %%
# git stashing(if you added that file in staging area also you want to save that but not commited yet) git saves that in temporary stash

# 1 add.()
# 2 git stash
# 3. git stash pop
# 4.git stash apply
